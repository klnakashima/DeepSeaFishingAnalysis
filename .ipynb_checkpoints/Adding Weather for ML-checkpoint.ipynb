# %%
# IMPORTS
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, DateFormatter

# %matplotlib inline
plt.rcParams['figure.figsize'] = 16,9

import warnings
warnings.filterwarnings('ignore')

# %%
# Retrieve 2019 Weather Data for each buoy near Orange County
buoyStations = [46047, 46025, 46253]
# for buoyNum in buoyStations:
#     df = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename='+str(buoyNum)+'h2019.txt.gz&dir=data/historical/stdmet/',delim_whitespace=True)
#     df.to_csv(str(buoyNum)+"data")

# %%
station25 = pd.read_csv("46025data",index_col=0)
station25.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR WSPD   GST   WVHT    DPD    APD   MWD    PRES  \
# 0   #yr  mo  dy  hr  mn  degT  m/s   m/s      m    sec    sec  degT     hPa
# 1  2019  01  01  00  00    12  7.0   9.3  99.00  99.00  99.00   999  1010.1
# 2  2019  01  01  00  10    11  7.5   9.9  99.00  99.00  99.00   999  1010.0
# 3  2019  01  01  00  20     8  7.5  10.2  99.00  99.00  99.00   999  1010.1
# 4  2019  01  01  00  30    23  8.3  11.4  99.00  99.00  99.00   999  1010.1
#
#    ATMP  WTMP  DEWP   VIS   TIDE
# 0  degC  degC  degC    mi     ft
# 1  16.4  16.0   5.4  99.0  99.00
# 2  16.3  16.0   5.5  99.0  99.00
# 3  16.3  16.0   4.9  99.0  99.00
# 4  16.2  16.0   4.9  99.0  99.00

# %%
station25 = station25.iloc[1:]
station25
# Out:
#         #YY  MM  DD  hh  mm WDIR WSPD   GST   WVHT    DPD    APD  MWD    PRES  \
# 1      2019  01  01  00  00   12  7.0   9.3  99.00  99.00  99.00  999  1010.1
# 2      2019  01  01  00  10   11  7.5   9.9  99.00  99.00  99.00  999  1010.0
# 3      2019  01  01  00  20    8  7.5  10.2  99.00  99.00  99.00  999  1010.1
# 4      2019  01  01  00  30   23  8.3  11.4  99.00  99.00  99.00  999  1010.1
# 5      2019  01  01  00  40   32  8.8  11.5   1.45  13.79   5.11  261  1010.1
# ...     ...  ..  ..  ..  ..  ...  ...   ...    ...    ...    ...  ...     ...
# 52122  2019  12  31  23  10  275  1.9   2.7     99     99     99  999  1016.7
# 52123  2019  12  31  23  20  286  2.5   3.2     99     99     99  999  1016.8
# 52124  2019  12  31  23  30  296  2.9   4.6     99     99     99  999  1016.7
# 52125  2019  12  31  23  40  313  4.1     6   1.25  14.81   6.09  254  1016.7
# 52126  2019  12  31  23  50  324  6.1   8.1     99     99     99  999  1016.8
#
# ...

# %%
# Find Mins/Means/&Maxes of WVHT, DPD, MWD, WTMP

# %%
# Remove rows with lots of 99s
#station25 = station25[station25.WVHT != 99 & station25.DPD != 99]
station25 = station25[station25.WVHT != 99]
station25
# Out:
#         #YY  MM  DD  hh  mm WDIR WSPD   GST   WVHT    DPD    APD  MWD    PRES  \
# 1      2019  01  01  00  00   12  7.0   9.3  99.00  99.00  99.00  999  1010.1
# 2      2019  01  01  00  10   11  7.5   9.9  99.00  99.00  99.00  999  1010.0
# 3      2019  01  01  00  20    8  7.5  10.2  99.00  99.00  99.00  999  1010.1
# 4      2019  01  01  00  30   23  8.3  11.4  99.00  99.00  99.00  999  1010.1
# 5      2019  01  01  00  40   32  8.8  11.5   1.45  13.79   5.11  261  1010.1
# ...     ...  ..  ..  ..  ..  ...  ...   ...    ...    ...    ...  ...     ...
# 52101  2019  12  31  19  40   37  4.1   5.9   1.37     10   5.34  256  1017.1
# 52107  2019  12  31  20  40   97  0.1   0.8   1.27   4.76   5.33   19  1016.6
# 52113  2019  12  31  21  40  239  0.2   1.2   1.21     10   5.37  253  1016.4
# 52119  2019  12  31  22  40  271  2.8   3.6   1.14  14.81   5.49  299  1016.7
# 52125  2019  12  31  23  40  313  4.1     6   1.25  14.81   6.09  254  1016.7
#
# ...

# %%
station25['WVHT'] = station25['WVHT'].astype(float)
station25 = station25[station25.WVHT != 99.00]
station25
# Out:
#         #YY  MM  DD  hh  mm WDIR  WSPD   GST  WVHT    DPD   APD  MWD    PRES  \
# 5      2019  01  01  00  40   32   8.8  11.5  1.45  13.79  5.11  261  1010.1
# 11     2019  01  01  01  40   31  10.6  13.8  1.62  14.81  4.96  256  1010.5
# 17     2019  01  01  02  40   33  10.2  12.8  1.79   4.76  5.05   15  1010.8
# 23     2019  01  01  03  40   45  10.0  12.5  1.70  14.81  5.02  275  1011.1
# 29     2019  01  01  04  40   48   8.3  11.1  1.62   4.55  5.00   31  1012.2
# ...     ...  ..  ..  ..  ..  ...   ...   ...   ...    ...   ...  ...     ...
# 52101  2019  12  31  19  40   37   4.1   5.9  1.37     10  5.34  256  1017.1
# 52107  2019  12  31  20  40   97   0.1   0.8  1.27   4.76  5.33   19  1016.6
# 52113  2019  12  31  21  40  239   0.2   1.2  1.21     10  5.37  253  1016.4
# 52119  2019  12  31  22  40  271   2.8   3.6  1.14  14.81  5.49  299  1016.7
# 52125  2019  12  31  23  40  313   4.1     6  1.25  14.81  6.09  254  1016.7
#
#        ATMP  WTMP  DEWP   VIS   TIDE
# ...

# %%
station25= station25.reset_index()
station25
# Out:
#       index   #YY  MM  DD  hh  mm WDIR  WSPD   GST  WVHT    DPD   APD  MWD  \
# 0         5  2019  01  01  00  40   32   8.8  11.5  1.45  13.79  5.11  261
# 1        11  2019  01  01  01  40   31  10.6  13.8  1.62  14.81  4.96  256
# 2        17  2019  01  01  02  40   33  10.2  12.8  1.79   4.76  5.05   15
# 3        23  2019  01  01  03  40   45  10.0  12.5  1.70  14.81  5.02  275
# 4        29  2019  01  01  04  40   48   8.3  11.1  1.62   4.55  5.00   31
# ...     ...   ...  ..  ..  ..  ..  ...   ...   ...   ...    ...   ...  ...
# 8652  52101  2019  12  31  19  40   37   4.1   5.9  1.37     10  5.34  256
# 8653  52107  2019  12  31  20  40   97   0.1   0.8  1.27   4.76  5.33   19
# 8654  52113  2019  12  31  21  40  239   0.2   1.2  1.21     10  5.37  253
# 8655  52119  2019  12  31  22  40  271   2.8   3.6  1.14  14.81  5.49  299
# 8656  52125  2019  12  31  23  40  313   4.1     6  1.25  14.81  6.09  254
#
#         PRES  ATMP  WTMP  DEWP   VIS   TIDE
# ...

# %%
station25 = station25.iloc[:, :-2]
station25
# Out:
#       index   #YY  MM  DD  hh  mm WDIR  WSPD   GST  WVHT    DPD   APD  MWD  \
# 0         5  2019  01  01  00  40   32   8.8  11.5  1.45  13.79  5.11  261
# 1        11  2019  01  01  01  40   31  10.6  13.8  1.62  14.81  4.96  256
# 2        17  2019  01  01  02  40   33  10.2  12.8  1.79   4.76  5.05   15
# 3        23  2019  01  01  03  40   45  10.0  12.5  1.70  14.81  5.02  275
# 4        29  2019  01  01  04  40   48   8.3  11.1  1.62   4.55  5.00   31
# ...     ...   ...  ..  ..  ..  ..  ...   ...   ...   ...    ...   ...  ...
# 8652  52101  2019  12  31  19  40   37   4.1   5.9  1.37     10  5.34  256
# 8653  52107  2019  12  31  20  40   97   0.1   0.8  1.27   4.76  5.33   19
# 8654  52113  2019  12  31  21  40  239   0.2   1.2  1.21     10  5.37  253
# 8655  52119  2019  12  31  22  40  271   2.8   3.6  1.14  14.81  5.49  299
# 8656  52125  2019  12  31  23  40  313   4.1     6  1.25  14.81  6.09  254
#
#         PRES  ATMP  WTMP  DEWP
# 0     1010.1  16.1  16.0   2.4
# ...

# %%
station25['date'] = station25.MM.map(str) + "-" + station25.DD.map(str)
station25.head()
# Out:
#    index   #YY  MM  DD  hh  mm WDIR  WSPD   GST  WVHT    DPD   APD  MWD  \
# 0      5  2019  01  01  00  40   32   8.8  11.5  1.45  13.79  5.11  261
# 1     11  2019  01  01  01  40   31  10.6  13.8  1.62  14.81  4.96  256
# 2     17  2019  01  01  02  40   33  10.2  12.8  1.79   4.76  5.05   15
# 3     23  2019  01  01  03  40   45  10.0  12.5  1.70  14.81  5.02  275
# 4     29  2019  01  01  04  40   48   8.3  11.1  1.62   4.55  5.00   31
#
#      PRES  ATMP  WTMP DEWP   date
# 0  1010.1  16.1  16.0  2.4  01-01
# 1  1010.5  15.7  15.9  2.5  01-01
# 2  1010.8  15.6  15.8  0.5  01-01
# 3  1011.1  15.6  15.8  1.2  01-01
# 4  1012.2  15.2  15.7  0.3  01-01
